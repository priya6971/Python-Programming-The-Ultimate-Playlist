# %%
2 + 3
# Out:
# 5

# %%
x = 2
y = 3
z = x + y

# %%
z
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
type(z)
# Out:
# int

# %%
x = 3.568912
z = x + y

# %%
z
# Out:
# 6.568912

# %%
type(x)
# Out:
# float

# %%
name = "Priya"
name
# Out:
# 'Priya'

# %%
type(name)
# Out:
# str

# %%
fullName = name + " Bhatia"

# %%
fullName
# Out:
# 'Priya Bhatia'

# %%
name + "123"
# Out:
# 'Priya123'

# %%
val = True
type(val)
# Out:
# bool

# %%
complexNum = 7 + 2j
type(complexNum)
# Out:
# complex

# %%
complexNum.real
# Out:
# 7.0

# %%
complexNum.imag
# Out:
# 2.0

# %%
complexNum
# Out:
# (7+2j)

# %%
val1 = True ##1
val2 = False ##0

val1 - val2
# Out:
# 1

# %%
val1 * val2
# Out:
# 0
