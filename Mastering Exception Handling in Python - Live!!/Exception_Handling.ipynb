# %% [markdown]
# Critical Code

# %%
num = 10
deno = 2
result = num / deno
print(result)
# Out:
# 5.0

# %%
num = 10
deno = 0
result = num / deno
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2792865339.py in <cell line: 0>()
#       1 num = 10
#       2 deno = 0
# ----> 3 result = num / deno
#       4 print(result)
#
# ZeroDivisionError: division by zero

# %%
if num > 0:
  print(num)
# Out:
# 10

# %%
lst = [12, 14, 17, 20, 22]
lst[3]
# Out:
# 20

# %% [markdown]
# Exception Handling

# %% [markdown]
# ```python
# try:
#   # critical code: code that might raise an exception
#   # ....
# except Exception1:
#   # code to handle the exception 1
#   # ....
# except Exception2:
#   # code to handle the exception 2
#   # ...

# %%
try:
  # critical code
  num = int(input("Enter your number: "))
  result = 10 / num
  print(f"Result: {result}")
  #backup strategy
except ZeroDivisionError:
  print("Error: Division by zero is not allowed")
except ValueError:
  print("Error: Invalid input. Please enter a number.")
except:
  print("An error occurred during execution")
# Out:
# Enter your number: 12.36
# Error: Invalid input. Please enter a number.

# %% [markdown]
# ```python
# try:
#   # critical code: code that might raise an exception
#   # ....
# except Exception1:
#   # code to handle the exception 1
#   # ....
# except Exception2:
#   # code to handle the exception 2
#   # ...
# else:
#   # code to execute if no exception were raised
#   # ...

# %%
try:
  # critical code
  num = int(input("Enter your number: "))
  result = 10 / num
  #backup strategy
except ZeroDivisionError:
  print("Error: Division by zero is not allowed")
except ValueError:
  print("Error: Invalid input. Please enter a number.")
except:
  print("An error occurred during execution")
else:
  print(f"Result: {result}")
# Out:
# Enter your number: 0
# Error: Division by zero is not allowed

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
my_list = [1, 2, 3]

try:
  print(my_list[4])
except IndexError:
  print("IndexError: Index out of range")
else:
  print("No indexerror occurred")
# Out:
# IndexError: Index out of range

# %%
my_dict = {"name": "priya", "age": 28}

try:
  print(my_dict['email'])
except KeyError:
  print("KeyError: Key not found")
else:
  print("No KeyError occurred")
# Out:
# KeyError: Key not found

# %% [markdown]
# ```python
# try:
#   # critical code: code that might raise an exception
#   # ....
# except Exception1:
#   # code to handle the exception 1
#   # ....
# except Exception2:
#   # code to handle the exception 2
#   # ...
# else:
#   # code to execute if no exception were raised
#   # ...
#   # we use the finally block in real usecases to free the resources
# finally:
#   # code to execute regardless of the exceptions
#   # ...

# %%
try:
  # critical code
  num = int(input("Enter your number: "))
  result = 10 / num
  #backup strategy
except ZeroDivisionError:
  print("Error: Division by zero is not allowed")
except ValueError:
  print("Error: Invalid input. Please enter a number.")
except:
  print("An error occurred during execution")
else:
  print(f"Result: {result}")
finally:
  print("Thank you for using this program.")
# Out:
# Enter your number: 0
# Error: Division by zero is not allowed
# Thank you for using this program.

# %% [markdown]
# Understand the raise keyword

# %%
x = int(input("Enter your number: "))

if x > 5:
  raise ValueError("Value is too high")
# Out:
# Enter your number: 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3603391144.py in <cell line: 0>()
#       2
#       3 if x > 5:
# ----> 4   raise ValueError("Value is too high")
#
# ValueError: Value is too high

# %%
def calculate_discount(price):
  if price < 0:
    raise ValueError("Price cannot be negative")
  return price * 0.1

# %%
price = int(input("Enter the price: "))
try:
  discount = calculate_discount(price)
except ValueError:
  discount = 0
finally:
  print("The discounted value as: ", discount)
# Out:
# Enter the price: -100
# The discounted value as:  0

# %% [markdown]
# Task:
#
# 1. Write a function that accepts a list of numbers and raises an exception if any element is negative.
# 2. Write a program that safely reads a file and ensures the file is always closed, even if an error occurs.
# 3. Create a custom exception InvalidAgeError.
#    * Raise it if age is less than 0 or greater than 120
#    * Catch it and print a meaningful message
# 4. Design a custom exception EnrollmentError for a course platform.
#    * Raise it if payment status is false
#    * Raise it if prerequisite course is not completed

# %% [markdown]
# Task based on OOPs:
#
# Design a Course Enrollment System using OOPS principles.
# The system should simulate how learners enroll in courses on a platform like PhysicsWallah.
#
# Core requirements (non-negotiable)
#
# 1. Base class: User
#
# Attributes: user_id, name, email
#
# Methods: get_profile() → returns basic user details
#
# 2. Derived class: Student(User)
#
# Additional attributes: completed_courses (list), is_payment_done (boolean)
#
# Methods: enroll(course), complete_course(course_id)
# Use inheritance properly. No duplication.
#
# 3. Class: Course
#
# Attributes: course_id, title, price
#
# prerequisites (list of course_ids)
#
# Methods: get_course_details()
